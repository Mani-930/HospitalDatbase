-- %% [markdown]
-- # [HospitalMgmtDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [HospitalMgmtDB]    Script Date: 11/21/2025 10:11:29 PM ******/
CREATE DATABASE [HospitalMgmtDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'HospitalMgmtDB', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\HospitalMgmtDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'HospitalMgmtDB_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\HospitalMgmtDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [HospitalMgmtDB] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [HospitalMgmtDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [HospitalMgmtDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [HospitalMgmtDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [HospitalMgmtDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [HospitalMgmtDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [HospitalMgmtDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [HospitalMgmtDB] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [HospitalMgmtDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [HospitalMgmtDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [HospitalMgmtDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [HospitalMgmtDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [HospitalMgmtDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [HospitalMgmtDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [HospitalMgmtDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [HospitalMgmtDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [HospitalMgmtDB] SET  ENABLE_BROKER 
GO
ALTER DATABASE [HospitalMgmtDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [HospitalMgmtDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [HospitalMgmtDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [HospitalMgmtDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [HospitalMgmtDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [HospitalMgmtDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [HospitalMgmtDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [HospitalMgmtDB] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [HospitalMgmtDB] SET  MULTI_USER 
GO
ALTER DATABASE [HospitalMgmtDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [HospitalMgmtDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [HospitalMgmtDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [HospitalMgmtDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [HospitalMgmtDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [HospitalMgmtDB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [HospitalMgmtDB] SET QUERY_STORE = ON
GO
ALTER DATABASE [HospitalMgmtDB] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Appointment]

-- %%
USE [HospitalMgmtDB]
GO

-- %%
/****** Object:  Table [dbo].[Appointment]    Script Date: 11/21/2025 10:11:29 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Appointment](
	[appointment_id] [int] IDENTITY(1,1) NOT NULL,
	[patient_id] [int] NOT NULL,
	[doctor_id] [int] NOT NULL,
	[appointment_date] [datetime] NOT NULL,
	[reason] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[appointment_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AppUser]

-- %%
/****** Object:  Table [dbo].[AppUser]    Script Date: 11/21/2025 10:11:29 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AppUser](
	[user_id] [int] IDENTITY(1,1) NOT NULL,
	[username] [nvarchar](50) NOT NULL,
	[password_hash] [nvarchar](255) NOT NULL,
	[full_name] [nvarchar](100) NULL,
	[role] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[user_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[username] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Billing]

-- %%
/****** Object:  Table [dbo].[Billing]    Script Date: 11/21/2025 10:11:29 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Billing](
	[bill_id] [int] IDENTITY(1,1) NOT NULL,
	[patient_id] [int] NOT NULL,
	[treatment_id] [int] NOT NULL,
	[amount] [decimal](10, 2) NOT NULL,
	[payment_status] [varchar](20) NOT NULL,
	[billing_date] [date] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[bill_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Doctor]

-- %%
/****** Object:  Table [dbo].[Doctor]    Script Date: 11/21/2025 10:11:29 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Doctor](
	[doctor_id] [int] IDENTITY(1,1) NOT NULL,
	[name] [varchar](100) NOT NULL,
	[specialty] [varchar](100) NOT NULL,
	[phone] [varchar](20) NULL,
	[email] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[doctor_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Patient]

-- %%
/****** Object:  Table [dbo].[Patient]    Script Date: 11/21/2025 10:11:29 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Patient](
	[patient_id] [int] IDENTITY(1,1) NOT NULL,
	[name] [varchar](100) NOT NULL,
	[date_of_birth] [date] NOT NULL,
	[gender] [char](1) NULL,
	[address] [varchar](255) NULL,
	[phone] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[patient_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Treatment]

-- %%
/****** Object:  Table [dbo].[Treatment]    Script Date: 11/21/2025 10:11:29 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Treatment](
	[treatment_id] [int] IDENTITY(1,1) NOT NULL,
	[appointment_id] [int] NOT NULL,
	[diagnosis] [varchar](255) NULL,
	[prescription] [varchar](max) NULL,
	[notes] [varchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[treatment_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Appointment_Doctor]

-- %%
ALTER TABLE [dbo].[Appointment]  WITH CHECK ADD  CONSTRAINT [FK_Appointment_Doctor] FOREIGN KEY([doctor_id])
REFERENCES [dbo].[Doctor] ([doctor_id])
GO
ALTER TABLE [dbo].[Appointment] CHECK CONSTRAINT [FK_Appointment_Doctor]
GO

-- %% [markdown]
-- # [FK_Appointment_Patient]

-- %%
ALTER TABLE [dbo].[Appointment]  WITH CHECK ADD  CONSTRAINT [FK_Appointment_Patient] FOREIGN KEY([patient_id])
REFERENCES [dbo].[Patient] ([patient_id])
GO
ALTER TABLE [dbo].[Appointment] CHECK CONSTRAINT [FK_Appointment_Patient]
GO

-- %% [markdown]
-- # [FK_Billing_Patient]

-- %%
ALTER TABLE [dbo].[Billing]  WITH CHECK ADD  CONSTRAINT [FK_Billing_Patient] FOREIGN KEY([patient_id])
REFERENCES [dbo].[Patient] ([patient_id])
GO
ALTER TABLE [dbo].[Billing] CHECK CONSTRAINT [FK_Billing_Patient]
GO

-- %% [markdown]
-- # [FK_Billing_Treatment]

-- %%
ALTER TABLE [dbo].[Billing]  WITH CHECK ADD  CONSTRAINT [FK_Billing_Treatment] FOREIGN KEY([treatment_id])
REFERENCES [dbo].[Treatment] ([treatment_id])
GO
ALTER TABLE [dbo].[Billing] CHECK CONSTRAINT [FK_Billing_Treatment]
GO

-- %% [markdown]
-- # [FK_Treatment_Appointment]

-- %%
ALTER TABLE [dbo].[Treatment]  WITH CHECK ADD  CONSTRAINT [FK_Treatment_Appointment] FOREIGN KEY([appointment_id])
REFERENCES [dbo].[Appointment] ([appointment_id])
GO
ALTER TABLE [dbo].[Treatment] CHECK CONSTRAINT [FK_Treatment_Appointment]
GO

-- %% [markdown]
-- # [CK__Billing__payment__4316F928]

-- %%
ALTER TABLE [dbo].[Billing]  WITH CHECK ADD CHECK  (([payment_status]='Cancelled' OR [payment_status]='Paid' OR [payment_status]='Pending'))
GO

-- %% [markdown]
-- # [CK__Patient__gender__37A5467C]

-- %%
ALTER TABLE [dbo].[Patient]  WITH CHECK ADD CHECK  (([gender]='O' OR [gender]='F' OR [gender]='M'))
GO

-- %% [markdown]
-- # [HospitalMgmtDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [HospitalMgmtDB] SET  READ_WRITE 
GO
